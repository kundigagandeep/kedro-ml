# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("/home/gagandeep/Public/Projects/kedro/kedro_ml/ds-salaries/data/01_raw/ds_salaries.csv",index_col=0)

df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
X = df.drop(columns=['salary_currency','salary_in_usd'])
y = df['salary_in_usd']

# %%
X = pd.get_dummies(X)
X.head()
# Out:
#    work_year  salary  remote_ratio  experience_level_EN  experience_level_EX  \
# 0       2020   70000             0                    0                    0
# 1       2020  260000             0                    0                    0
# 2       2020   85000            50                    0                    0
# 3       2020   20000             0                    0                    0
# 4       2020  150000            50                    0                    0
#
#    experience_level_MI  experience_level_SE  employment_type_CT  \
# 0                    1                    0                   0
# 1                    0                    1                   0
# 2                    0                    1                   0
# 3                    1                    0                   0
# 4                    0                    1                   0
#
#    employment_type_FL  employment_type_FT  ...  company_location_RU  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print(f'Mean absolute error: {mae:.2f}')
print(f'Mean squared error: {mse:.2f}')
print(f'Root mean squared error: {rmse:.2f}')
# Out:
# Mean absolute error: 43664.52
# Mean squared error: 3481398372.74
# Root mean squared error: 59003.38

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(random_state=4,n_estimators=20)

# %%
rfr.fit(X_train, y_train)
rfr_pred = rfr.predict(X_test)

# %%
print('rfr training score: ',rfr.score(X_train, y_train))
print('rfr testing score:  ',rfr.score(X_test, y_test))
print('mean_squared_error: ', mean_squared_error(rfr_pred, y_test, squared=False))
# Out:
# rfr training score:  0.9552559730777191
# rfr testing score:   0.8081657204819291
# mean_squared_error:  33072.900076195314
